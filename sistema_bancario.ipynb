# %%
menu ='''
----Faça Sua Escolha----
1) Depositar
2) Sacar
3) Extrato
4) Sair

->'''
saldo = 0
limite = 500
extrato = ""
numero_saque = 0
LIMITE_SAQUE = 3
while True:
    opcao = input(menu)
    if opcao == "1":
        valor = float(input("Quanto quer depositar: "))
        
        if valor > 0:
            saldo += valor
            extrato += f"Deposito R$ {valor:.2f}\n"
        else:
            print("Operação Falhou! O Valor Informato é Inválido")
        
    elif opcao == "2":
        valor = float(input("Informa o Valor do Saque: "))
        exedeu_saldo = valor > saldo
        exedeu_limite = valor > limite
        exedeu_saque = numero_saque > LIMITE_SAQUE

        if exedeu_saldo:
            print("Opção Falhou! Você Não Tem Saldo Suficiente.")
            
        elif exedeu_limite:
            print("Opção Falhou! Você Não Tem Limite Suficiente.")
            
        elif exedeu_saque:
            print(("Opção Falhou! Excedeu o Número Maximo de Saque Consentido."))
            
        elif valor > 0:
            saldo -= valor
            extrato += f"Saque R$ {valor:.2f}\n"
            numero_saque += 1
        
        else:
            print("Operação Falha! O Valor Informado é Invalido.")

            
    elif opcao == "3":
        print("\n----------EXTRATO----------")
        print("Não Foram Realizadas Movimentações:" if not extrato else extrato)
        print(f"\nSaldo: R$ {saldo:.2f}")
        print("---------------------------")
        
    elif opcao == "4":
        print("sair")
        break
        
    else:
        print("Operação Invalida! Por Favor Selecione Uma Opçao do Menu Obrigado.")
# Out:
# ----Faça Sua Escolha----
# 1) Depositar
# 2) Sacar
# 3) Extrato
# 4) Sair
#
# ->1000
# Operação Invalida! Por Favor Selecione Uma Opçao do Menu Obrigado.
#
# ----Faça Sua Escolha----
# 1) Depositar
# 2) Sacar
# 3) Extrato
# 4) Sair
#
# ->2
# Informa o Valor do Saque: 100
# Opção Falhou! Você Não Tem Saldo Suficiente.
#
# ----Faça Sua Escolha----
# 1) Depositar
# 2) Sacar
# 3) Extrato
# 4) Sair
#
# ->1
# Quanto quer depositar: 1000
#
# ----Faça Sua Escolha----
# 1) Depositar
# 2) Sacar
# 3) Extrato
# 4) Sair
#
# ->2
# Informa o Valor do Saque: 100
#
# ----Faça Sua Escolha----
# 1) Depositar
# 2) Sacar
# 3) Extrato
# 4) Sair
#
# ->100
# Operação Invalida! Por Favor Selecione Uma Opçao do Menu Obrigado.
#
# ----Faça Sua Escolha----
# 1) Depositar
# 2) Sacar
# 3) Extrato
# 4) Sair
#
# ->100
# Operação Invalida! Por Favor Selecione Uma Opçao do Menu Obrigado.
#
# ----Faça Sua Escolha----
# 1) Depositar
# 2) Sacar
# 3) Extrato
# 4) Sair
#
# ->2
# Informa o Valor do Saque: 100
#
# ...
